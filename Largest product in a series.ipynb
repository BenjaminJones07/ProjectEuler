# %%
number = """""".replace("\n", "")

max = 0
for x in range(0, len(number)-13):
    product = 1
    for z in [int(y) for y in number[x:x+13]]:
        product *= z
    if product > max:
        max = product

print(max)
# Out:
# 23514624000
